# %% [markdown]
# <a href="https://colab.research.google.com/github/kushalshah0/colab_tools/blob/main/maricopa_id_barcode_gen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install python-barcode Pillow

# %%
import barcode
from barcode.writer import ImageWriter

def generate_personal_barcode(name, id_no, phone, dob, expiry, filename="personal_barcode"):
    barcode_data = f"Name:{name}|ID:{id_no}|Address:{address}|Expiry:{expiry}"

    Code128 = barcode.get_barcode_class('code128')
    my_barcode = Code128(barcode_data, writer=ImageWriter())

    my_barcode.save(filename, options={'write_text': False, 'module_height': 5, 'quiet_zone': 1})
    print(f"Barcode saved as {filename}.png")

user_details = {
    "name": "Jerald Rodriguez",
    "id_no": "37273658",
    "address": "44661 Sterling Hwy, Soldotna, AK 99669"
    "expiry": "2030-12-29"
}

generate_personal_barcode(
    user_details["name"],
    user_details["id_no"],
    user_details["address"],
    user_details["expiry"],
    filename="barcode"
)
# Out:
# Barcode saved as barcode.png
